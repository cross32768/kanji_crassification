# %%
import os
import json
from PIL import Image

# %%
with open('../../data/kanjivg_radical/utf16_to_radical.json') as f:
    utf16_to_radical = json.load(f)

# %%
kanji_dir = '../../data/kkanji2_expansion/'
save_dir = '../../data/kkanji2_expansion_can_get_radical/'
kanji_folders = os.listdir(kanji_dir)
print(len(kanji_folders))
# Out:
# 140424

# %%
'''
for i, kanji in enumerate(kanji_folders):
    if kanji[:4] in utf16_to_radical:
        kanji_image = Image.open(kanji_dir + kanji)
        kanji_image.save(save_dir + kanji)
    print('[%d/%d]' % (i, len(kanji_folders)))
'''
# Out:
# [0/140424]
# [1/140424]
# [2/140424]
# [3/140424]
# [4/140424]
# [5/140424]
# [6/140424]
# [7/140424]
# [8/140424]
# [9/140424]
# [10/140424]
# [11/140424]
# [12/140424]
# [13/140424]
# [14/140424]
# [15/140424]
# [16/140424]
# [17/140424]
# [18/140424]
# [19/140424]
# [20/140424]
# [21/140424]
# [22/140424]
# [23/140424]
# [24/140424]
# [25/140424]
# [26/140424]
# [27/140424]
# [28/140424]
# [29/140424]
# [30/140424]
# [31/140424]
# [32/140424]
# [33/140424]
# [34/140424]
# [35/140424]
# [36/140424]
# [37/140424]
# [38/140424]
# [39/140424]
# [40/140424]
# [41/140424]
# [42/140424]
# [43/140424]
# [44/140424]
# [45/140424]
# [46/140424]
# [47/140424]
# [48/140424]
# [49/140424]
# [50/140424]
# [51/140424]
# [52/140424]
# [53/140424]
# [54/140424]
# [55/140424]
# [56/140424]
# [57/140424]
# [58/140424]
# [59/140424]
# [60/140424]
# [61/140424]
# [62/140424]
# [63/140424]
# [64/140424]
# [65/140424]
# [66/140424]
# [67/140424]
# [68/140424]
# [69/140424]
# [70/140424]
# [71/140424]
# ...

# %%
kanji_can_get_radical_folders = os.listdir(save_dir)
print(len(kanji_can_get_radical_folders))
# Out:
# 117659

# %%
kanji_set = set()
for kanji in kanji_folders:
    kanji_set.add(kanji[:4])

# %%
print(len(kanji_set))
# Out:
# 3832

# %%
kanji_can_get_radical_set = set()
for kanji in kanji_can_get_radical_folders:
    kanji_can_get_radical_set.add(kanji[:4])

# %%
print(len(kanji_can_get_radical_set))
# Out:
# 3566
